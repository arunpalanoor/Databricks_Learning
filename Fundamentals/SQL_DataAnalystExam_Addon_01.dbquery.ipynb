-- %%
SELECT *
FROM fundamentals.trading212.scrip_list;

-- Add and Manage TAGS
-- e.g. PII, Owner, Access, etc.

ALTER TABLE fundamentals.trading212.scrip_list
SET TAGS('pii'= 'False','owner'='Self');

ALTER TABLE fundamentals.trading212.scrip_list
UNSET TAGS('pii','owner');
